# %% [markdown]
# # EDA for the final dataset

# %% [markdown]
# ## Define path for the final dataset and load it

# %%
path = "../data/final.csv"

# %%
import pandas as pd
df = pd.read_csv(path)

# %% [markdown]
# ## Plots

# %%
#import python file eda.py from data folder
from data import eda

# %% [markdown]
# ### Priority Histogram

# %%
eda.plot_label_histogram(df)

# %% [markdown]
# ### Text grade distribution

# %%
eda.plot_text_grade_distribution(df)

# %% [markdown]
# ### Text length distribution

# %%
eda.plot_text_length_distribution(df)

# %% [markdown]
# ### Text sentence distribution

# %%
eda.plot_text_sentence_distribution(df)

# %% [markdown]
# ### Text reading time distribution

# %%
eda.plot_text_reading_time_distribution(df)
